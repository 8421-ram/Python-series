# %% [markdown]
# # Pandas

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# __Pandas is a sofware library written for the python programming language for data manupultion and analysis__

# %% [markdown]
# ### Installation of Pandas
# __pip install Pandas__

# %% [markdown]
# #### Invokig the library

# %%
import pandas

# %% [markdown]
# __Checking the version of the pandas__

# %%
print(pandas.__version__)
# Out:
# 2.0.3

# %%
import pandas as pd

# %% [markdown]
# __Create DataFrame using the Dictionary__

# %%
di = {"Name":["Rama","Gopala","Krishna","Masani"],"RollNo":[1,2,3,4],"Perc":[78.0,80.0,77.0,90.5]}

# %%
di
# Out:
# {'Name': ['Rama', 'Gopala', 'Krishna', 'Masani'],
#  'RollNo': [1, 2, 3, 4],
#  'Perc': [78.0, 80.0, 77.0, 90.5]}

# %%
df = pd.DataFrame(di)

# %%
df
# Out:
#       Name  RollNo  Perc
# 0     Rama       1  78.0
# 1   Gopala       2  80.0
# 2  Krishna       3  77.0
# 3   Masani       4  90.5

# %% [markdown]
# __Create DataFrame using the List of Tuples__

# %%
lst = [('Rama',1,89.2),("Gopala",2,78.0),("krishna",3,88.0),("Masani",4,90.2)]

# %%
lst
# Out:
# [('Rama', 1, 89.2),
#  ('Gopala', 2, 78.0),
#  ('krishna', 3, 88.0),
#  ('Masani', 4, 90.2)]

# %%
df_1 = pd.DataFrame(lst)

# %%
df_1
# Out:
#          0  1     2
# 0     Rama  1  89.2
# 1   Gopala  2  78.0
# 2  krishna  3  88.0
# 3   Masani  4  90.2

# %% [markdown]
# __How to read the CSV file (Comma Separated Values)__

# %%
df = pd.read_csv(r"C:\Users\USER\3D Objects\PYTHON\Pandas\COVID-19 India Statewise Vaccine Data.csv")

# %%
df
# Out:
#                                    State/UTs  Total Vaccination Doses  \
# 0                        Andaman and Nicobar                   629054
# 1                             Andhra Pradesh                 84147957
# 2                          Arunachal Pradesh                  1596166
# 3                                      Assam                 42998698
# 4                                      Bihar                119963226
# 5                                 Chandigarh                  2001114
# 6                               Chhattisgarh                 36927545
# 7   Dadra and Nagar Haveli and Daman and Diu                  1319914
# 8                                      Delhi                 30710281
# 9                                        Goa                  2572559
# 10                                   Gujarat                 98534412
# 11                                   Haryana                 40581317
# ...

# %% [markdown]
# __How to read the Excel file__

# %%
data = pd.read_excel(r"C:\Users\USER\3D Objects\PYTHON\Pandas\Student_marks.xlsx")

# %%
data
# Out:
#     Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 0       101         sundeep      90       85     80       83      75
# 1       102         saradhi      50       60     75       54      64
# 2       103          ramesh      95       78     68       58      78
# 3       104          suresh      55       87     68       64      59
# 4       105         sathwik      88       84     98       73      81
# 5       106         abhiram      73       84     91       88      84
# 6       107        srinidhi      90       83     74       86      94
# 7       108         lakshmi      75       78     85       64      53
# 8       109          dinesh      84       85     76       94      54
# 9       110          harish      83       98     81       63      79
# 10      111          murali      85       86     92       75      35
# 11      112            vasu      50       54     64       87      45
# 12      113            kali      89       97     69       73      82
# ...

# %% [markdown]
# ## head(): By defult it shows the top 5 records

# %%
data.head()
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 0      101         sundeep      90       85     80       83      75
# 1      102         saradhi      50       60     75       54      64
# 2      103          ramesh      95       78     68       58      78
# 3      104          suresh      55       87     68       64      59
# 4      105         sathwik      88       84     98       73      81

# %%
data.head(2)
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 0      101         sundeep      90       85     80       83      75
# 1      102         saradhi      50       60     75       54      64

# %%
data.head(10)
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 0      101         sundeep      90       85     80       83      75
# 1      102         saradhi      50       60     75       54      64
# 2      103          ramesh      95       78     68       58      78
# 3      104          suresh      55       87     68       64      59
# 4      105         sathwik      88       84     98       73      81
# 5      106         abhiram      73       84     91       88      84
# 6      107        srinidhi      90       83     74       86      94
# 7      108         lakshmi      75       78     85       64      53
# 8      109          dinesh      84       85     76       94      54
# 9      110          harish      83       98     81       63      79

# %% [markdown]
# ## Tail(): By defult it shows the last 5 records

# %%
data.tail()
# Out:
#     Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 15      116            hari      78       89     95       67      58
# 16      117           pavan      59       52     68       68      70
# 17      118           ashok      85       86     98       78      44
# 18      119          govind      89       89     95       66      95
# 19      120         bhargav      72       78     86       64      72

# %%
data.tail(2)
# Out:
#     Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 18      119          govind      89       89     95       66      95
# 19      120         bhargav      72       78     86       64      72

# %%
data.tail(10)
# Out:
#     Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 10      111          murali      85       86     92       75      35
# 11      112            vasu      50       54     64       87      45
# 12      113            kali      89       97     69       73      82
# 13      114            ramu      25       45     60       35      48
# 14      115         krishna       1       25     65       50      55
# 15      116            hari      78       89     95       67      58
# 16      117           pavan      59       52     68       68      70
# 17      118           ashok      85       86     98       78      44
# 18      119          govind      89       89     95       66      95
# 19      120         bhargav      72       78     86       64      72

# %% [markdown]
# ## Describe()  It selects the numerical columns and provides the statistical results

# %%
data.describe()
# Out:
#          Roll_No     Telugu    English     Maths    Science     Social
# count   20.00000  20.000000  20.000000  20.00000  20.000000  20.000000
# mean   110.50000  70.800000  76.150000  79.40000  69.500000  66.250000
# std      5.91608  24.394995  18.935556  12.41561  14.376516  17.222614
# min    101.00000   1.000000  25.000000  60.00000  35.000000  35.000000
# 25%    105.75000  58.000000  73.500000  68.00000  63.750000  53.750000
# 50%    110.50000  80.500000  84.000000  78.00000  67.500000  67.000000
# 75%    115.25000  88.250000  86.250000  91.25000  79.250000  79.500000
# max    120.00000  95.000000  98.000000  98.00000  94.000000  95.000000

# %% [markdown]
# ## Shape() it gives the dimension of the data(like rows and colums)

# %%
data.shape
# Out:
# (20, 7)

# %% [markdown]
# ## Indexing [Start:stop:skip]

# %%
data[0:10:2]
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 0      101         sundeep      90       85     80       83      75
# 2      103          ramesh      95       78     68       58      78
# 4      105         sathwik      88       84     98       73      81
# 6      107        srinidhi      90       83     74       86      94
# 8      109          dinesh      84       85     76       94      54

# %% [markdown]
# ## Extract only one column.

# %%
data["Name_of_Student"]
# Out:
# 0      sundeep
# 1      saradhi
# 2       ramesh
# 3       suresh
# 4      sathwik
# 5      abhiram
# 6     srinidhi
# 7      lakshmi
# 8       dinesh
# 9       harish
# 10      murali
# 11        vasu
# 12        kali
# 13        ramu
# 14     krishna
# 15        hari
# 16       pavan
# 17       ashok
# 18      govind
# 19     bhargav
# Name: Name_of_Student, dtype: object

# %% [markdown]
# ## Extract only multiple  column.

# %%
data[["Name_of_Student","Telugu","Maths"]].head()
# Out:
#   Name_of_Student  Telugu  Maths
# 0         sundeep      90     80
# 1         saradhi      50     75
# 2          ramesh      95     68
# 3          suresh      55     68
# 4         sathwik      88     98

# %% [markdown]
# ## Extract only multiple column along with Indexing [Start:stop:skip]

# %%
data[["Name_of_Student","Telugu","Maths"]][0:10:2]
# Out:
#   Name_of_Student  Telugu  Maths
# 0         sundeep      90     80
# 2          ramesh      95     68
# 4         sathwik      88     98
# 6        srinidhi      90     74
# 8          dinesh      84     76

# %% [markdown]
# ## iterrows using for individual rows selecting

# %%
for record in data.iterrows():
    print(record)
# Out:
# (0, Roll_No                101
# Name_of_Student    sundeep
# Telugu                  90
# English                 85
# Maths                   80
# Science                 83
# Social                  75
# Name: 0, dtype: object)
# (1, Roll_No                102
# Name_of_Student    saradhi
# Telugu                  50
# English                 60
# Maths                   75
# Science                 54
# Social                  64
# Name: 1, dtype: object)
# (2, Roll_No               103
# Name_of_Student    ramesh
# Telugu                 95
# English                78
# Maths                  68
# Science                58
# Social                 78
# Name: 2, dtype: object)
# (3, Roll_No               104
# Name_of_Student    suresh
# Telugu                 55
# English                87
# Maths                  68
# Science                64
# Social                 59
# Name: 3, dtype: object)
# (4, Roll_No                105
# Name_of_Student    sathwik
# ...

# %% [markdown]
# ## loc: (Stop index include) columns represnt with names

# %%
data.head(1)
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 0      101         sundeep      90       85     80       83      75

# %%
data.loc[0]
# Out:
# Roll_No                101
# Name_of_Student    sundeep
# Telugu                  90
# English                 85
# Maths                   80
# Science                 83
# Social                  75
# Name: 0, dtype: object

# %%
data.loc[19]
# Out:
# Roll_No                120
# Name_of_Student    bhargav
# Telugu                  72
# English                 78
# Maths                   86
# Science                 64
# Social                  72
# Name: 19, dtype: object

# %%
data.loc[13,["Name_of_Student"]]
# Out:
# Name_of_Student    ramu
# Name: 13, dtype: object

# %%
data.loc[13,["Name_of_Student","Maths"]]
# Out:
# Name_of_Student    ramu
# Maths                60
# Name: 13, dtype: object

# %%
data.loc[0:5]
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 0      101         sundeep      90       85     80       83      75
# 1      102         saradhi      50       60     75       54      64
# 2      103          ramesh      95       78     68       58      78
# 3      104          suresh      55       87     68       64      59
# 4      105         sathwik      88       84     98       73      81
# 5      106         abhiram      73       84     91       88      84

# %%
data.loc[0:5,["Name_of_Student","Telugu"]]
# Out:
#   Name_of_Student  Telugu
# 0         sundeep      90
# 1         saradhi      50
# 2          ramesh      95
# 3          suresh      55
# 4         sathwik      88
# 5         abhiram      73

# %%
data.loc[0:5,"Name_of_Student":"Science"]
# Out:
#   Name_of_Student  Telugu  English  Maths  Science
# 0         sundeep      90       85     80       83
# 1         saradhi      50       60     75       54
# 2          ramesh      95       78     68       58
# 3          suresh      55       87     68       64
# 4         sathwik      88       84     98       73
# 5         abhiram      73       84     91       88

# %% [markdown]
# ## iloc: (stop index exclude) columns represnt with numbers

# %%
data.head(1)
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 0      101         sundeep      90       85     80       83      75

# %%
data.iloc[0,0]
# Out:
# 101

# %%
data.iloc[0:5,0:3]
# Out:
#    Roll_No Name_of_Student  Telugu
# 0      101         sundeep      90
# 1      102         saradhi      50
# 2      103          ramesh      95
# 3      104          suresh      55
# 4      105         sathwik      88

# %%
data.iloc[0:5,2]
# Out:
# 0    90
# 1    50
# 2    95
# 3    55
# 4    88
# Name: Telugu, dtype: int64

# %%
data.iloc[[1,2,3]]
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 1      102         saradhi      50       60     75       54      64
# 2      103          ramesh      95       78     68       58      78
# 3      104          suresh      55       87     68       64      59

# %%
data.iloc[[1,5,10,15]]
# Out:
#     Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 1       102         saradhi      50       60     75       54      64
# 5       106         abhiram      73       84     91       88      84
# 10      111          murali      85       86     92       75      35
# 15      116            hari      78       89     95       67      58

# %%
data.iloc[:,[1,2,4]].head()
# Out:
#   Name_of_Student  Telugu  Maths
# 0         sundeep      90     80
# 1         saradhi      50     75
# 2          ramesh      95     68
# 3          suresh      55     68
# 4         sathwik      88     98

# %%
data.iloc[0:3,[1,2,3]]
# Out:
#   Name_of_Student  Telugu  English
# 0         sundeep      90       85
# 1         saradhi      50       60
# 2          ramesh      95       78

# %% [markdown]
# # Soting the DataFrame
# __By defult it gives the Ascending order it means (small values to bigger values)__

# %%
data.sort_values("Maths")
# Out:
#     Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 13      114            ramu      25       45     60       35      48
# 11      112            vasu      50       54     64       87      45
# 14      115         krishna       1       25     65       50      55
# 2       103          ramesh      95       78     68       58      78
# 3       104          suresh      55       87     68       64      59
# 16      117           pavan      59       52     68       68      70
# 12      113            kali      89       97     69       73      82
# 6       107        srinidhi      90       83     74       86      94
# 1       102         saradhi      50       60     75       54      64
# 8       109          dinesh      84       85     76       94      54
# 0       101         sundeep      90       85     80       83      75
# 9       110          harish      83       98     81       63      79
# 7       108         lakshmi      75       78     85       64      53
# ...

# %% [markdown]
# ## How to convert Descening Order

# %%
data.sort_values("Maths",ascending=False)
# Out:
#     Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 17      118           ashok      85       86     98       78      44
# 4       105         sathwik      88       84     98       73      81
# 15      116            hari      78       89     95       67      58
# 18      119          govind      89       89     95       66      95
# 10      111          murali      85       86     92       75      35
# 5       106         abhiram      73       84     91       88      84
# 19      120         bhargav      72       78     86       64      72
# 7       108         lakshmi      75       78     85       64      53
# 9       110          harish      83       98     81       63      79
# 0       101         sundeep      90       85     80       83      75
# 8       109          dinesh      84       85     76       94      54
# 1       102         saradhi      50       60     75       54      64
# 6       107        srinidhi      90       83     74       86      94
# ...

# %% [markdown]
# ## Multiple columns Sorting 1st columns is taking and sort the values

# %%
data.sort_values(["Name_of_Student","Maths"]).head()
# Out:
#     Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 5       106         abhiram      73       84     91       88      84
# 17      118           ashok      85       86     98       78      44
# 19      120         bhargav      72       78     86       64      72
# 8       109          dinesh      84       85     76       94      54
# 18      119          govind      89       89     95       66      95

# %%
data.sort_values(["Maths","Name_of_Student"]).head()
# Out:
#     Roll_No Name_of_Student  Telugu  English  Maths  Science  Social
# 13      114            ramu      25       45     60       35      48
# 11      112            vasu      50       54     64       87      45
# 14      115         krishna       1       25     65       50      55
# 16      117           pavan      59       52     68       68      70
# 2       103          ramesh      95       78     68       58      78

# %% [markdown]
# # Manupulating the Data Frame

# %% [markdown]
# ### Adding the Columns

# %%
data["Total"]=0

# %%
data.head(2)
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social  Total
# 0      101         sundeep      90       85     80       83      75      0
# 1      102         saradhi      50       60     75       54      64      0

# %%
data["Total"]=data["Telugu"]+data["English"]+data["Maths"]+data["Science"]+data["Social"]

# %%
data.head()
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social  Total
# 0      101         sundeep      90       85     80       83      75    413
# 1      102         saradhi      50       60     75       54      64    303
# 2      103          ramesh      95       78     68       58      78    377
# 3      104          suresh      55       87     68       64      59    333
# 4      105         sathwik      88       84     98       73      81    424

# %% [markdown]
# ### Remocing the Columns

# %%
data["Perc"]="Pass/Fail"

# %%
data.head()
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social  Total  \
# 0      101         sundeep      90       85     80       83      75    413
# 1      102         saradhi      50       60     75       54      64    303
# 2      103          ramesh      95       78     68       58      78    377
# 3      104          suresh      55       87     68       64      59    333
# 4      105         sathwik      88       84     98       73      81    424
#
#         Perc
# 0  Pass/Fail
# 1  Pass/Fail
# 2  Pass/Fail
# 3  Pass/Fail
# 4  Pass/Fail

# %% [markdown]
# __We drop the **Perc** column__

# %%
data.drop(columns="Perc").head()
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social  Total
# 0      101         sundeep      90       85     80       83      75    413
# 1      102         saradhi      50       60     75       54      64    303
# 2      103          ramesh      95       78     68       58      78    377
# 3      104          suresh      55       87     68       64      59    333
# 4      105         sathwik      88       84     98       73      81    424

# %% [markdown]
# __It's calling the data frame again to permanently delete the 'Perc' column. We can do this using the 'inplace=True' parameter.__

# %%
data.head()
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social  Total  \
# 0      101         sundeep      90       85     80       83      75    413
# 1      102         saradhi      50       60     75       54      64    303
# 2      103          ramesh      95       78     68       58      78    377
# 3      104          suresh      55       87     68       64      59    333
# 4      105         sathwik      88       84     98       73      81    424
#
#         Perc
# 0  Pass/Fail
# 1  Pass/Fail
# 2  Pass/Fail
# 3  Pass/Fail
# 4  Pass/Fail

# %%
data.drop(columns="Perc",inplace=True)

# %%
data.head()
# Out:
#    Roll_No Name_of_Student  Telugu  English  Maths  Science  Social  Total
# 0      101         sundeep      90       85     80       83      75    413
# 1      102         saradhi      50       60     75       54      64    303
# 2      103          ramesh      95       78     68       58      78    377
# 3      104          suresh      55       87     68       64      59    333
# 4      105         sathwik      88       84     98       73      81    424

# %% [markdown]
# ### How to check Duplicates

# %%
data.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# dtype: bool

# %% [markdown]
# __There is no duplicates__

# %% [markdown]
# # How to check the duplicate values

# %%
import pandas as pd
